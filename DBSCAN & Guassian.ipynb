# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from plotnine import *
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

from sklearn.cluster import DBSCAN


from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_score

# %matplotlib inline

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %% [markdown]
# # DBSCAN with Multiple Data Sets
#
# Read [here](https://www.aaai.org/Papers/KDD/1996/KDD96-037.pdf) if math excites you.
#
# ## Dataset 1

# %%
colors = ["#26408B", "#A6CFD5", "#0F084B"]
k=3

# %%
d1 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM1.csv")
d1.head()
plt.scatter(data = d1,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=k, random_state=0)
kmean.fit(d1[["x","y"]])
d1["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d1, d1["km"])}')
plt.scatter(data = d1,x='x',y='y',c= d1["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.6126282700466036

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(k)
h.fit(d1[["x","y"]])
d1["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d1, d1["h"])}')
plt.scatter(data = d1,x='x',y='y',c= d1["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.61708721809189

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.5, min_samples = 25)
db.fit(d1[["x","y"]])
d1["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d1, d1["db"])}')
plt.scatter(data = d1,x='x',y='y',c= d1["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: 0.31467017964444344

# %%
#Gaussian Mixture
gm = GaussianMixture(n_components=5)
gm.fit(d1[["x","y"]])
d1["gm"] = gm.predict(d1[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d1, d1["gm"])}')
plt.scatter(data = d1,x='x',y='y',c= d1["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.5586934606436139

# %% [markdown]
# ## Dataset 2

# %%
d2 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM2.csv")
plt.scatter(data = d2,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=k, random_state=0)
kmean.fit(d2[["x","y"]])
d2["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d2, d2["km"])}')
plt.scatter(data = d2,x='x',y='y',c= d2["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.6331069703494033

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(k)
h.fit(d2[["x","y"]])
d2["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d2, d2["h"])}')
plt.scatter(data = d2,x='x',y='y',c= d2["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.6591640205768541

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.5, min_samples = 20)
db.fit(d2[["x","y"]])
d2["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d2, d2["db"])}')
plt.scatter(data = d2,x='x',y='y',c= d2["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: 0.6204507829653625

# %%
#Gaussian Mixture
gm = GaussianMixture(k)
gm.fit(d2[["x","y"]])
d2["gm"] = gm.predict(d2[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d2, d2["gm"])}')
plt.scatter(data = d2,x='x',y='y',c= d2["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.6669737826683746

# %% [markdown]
# ## Dataset 3

# %%
d3 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM3.csv")
plt.scatter(data = d3,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=k, random_state=0)
kmean.fit(d3[["x","y"]])
d3["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d3, d3["km"])}')
plt.scatter(data = d3,x='x',y='y',c= d3["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.9207236459925316

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(k)
h.fit(d3[["x","y"]])
d3["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d3, d3["h"])}')
plt.scatter(data = d3,x='x',y='y',c= d3["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.9310799549582602

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.5, min_samples = 20)
db.fit(d3[["x","y"]])
d3["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d3, d3["db"])}')
plt.scatter(data = d3,x='x',y='y',c= d3["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: 0.9358550727963991

# %%
#Gaussian Mixture
gm = GaussianMixture(k)
gm.fit(d3[["x","y"]])
d3["gm"] = gm.predict(d3[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d3, d3["gm"])}')
plt.scatter(data = d3,x='x',y='y',c= d3["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.9389418019947724

# %% [markdown]
# ## Dataset 4

# %%
d4 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM4.csv")
plt.scatter(data = d4,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=15, random_state=0)
kmean.fit(d4[["x","y"]])
d4["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d4, d4["km"])}')
plt.scatter(data = d4,x='x',y='y',c= d4["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.6822205762436333

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(15)
h.fit(d4[["x","y"]])
d4["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d4, d4["h"])}')
plt.scatter(data = d4,x='x',y='y',c= d4["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.542389442030595

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.5, min_samples = 2)
db.fit(d4[["x","y"]])
d4["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d4, d4["db"])}')
plt.scatter(data = d4,x='x',y='y',c= d4["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: -0.2184788312633635

# %%
#Gaussian Mixture
gm = GaussianMixture(20)
gm.fit(d4[["x","y"]])
d4["gm"] = gm.predict(d4[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d4, d4["gm"])}')
plt.scatter(data = d4,x='x',y='y',c= d4["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.7073749911348938

# %%
#Gaussian Mixture
gm = GaussianMixture(9)
gm.fit(d4[["x","y"]])
d4["gm"] = gm.predict(d4[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d4, d4["gm"])}')
plt.scatter(data = d4,x='x',y='y',c= d4["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.35051476379553775

# %% [markdown]
# ### Compare

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

hac = AgglomerativeClustering(2)
km = KMeans(2)
gm = GaussianMixture(2)

hac.fit(d4[["x","y"]])
km.fit(d4[["x","y"]])
gm.fit(d4[["x","y"]])

d4["hac"] = hac.labels_
d4["km"] = km.labels_
d4["gm"] = gm.predict(d4[["x","y"]])


print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))

# %% [markdown]
# ## Dataset 5

# %%
d5 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM5.csv")
plt.scatter(data = d5,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=k, random_state=0)
kmean.fit(d5[["x","y"]])
d5["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d5, d5["km"])}')
plt.scatter(data = d5,x='x',y='y',c= d5["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.7340179581639614

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(k)
h.fit(d5[["x","y"]])
d5["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d5, d5["h"])}')
plt.scatter(data = d5,x='x',y='y',c= d5["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.7638896611186098

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.5, min_samples = 5)
db.fit(d5[["x","y"]])
d5["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d5, d5["db"])}')
plt.scatter(data = d5,x='x',y='y',c= d5["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: 0.7420747900430885

# %%
#Gaussian Mixture
gm = GaussianMixture(3)
gm.fit(d5[["x","y"]])
d5["gm"] = gm.predict(d5[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d5, d5["gm"])}')
plt.scatter(data = d5,x='x',y='y',c= d5["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.779678787178915

# %% [markdown]
# ## Dataset 6

# %%
d6 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM6.csv")
plt.scatter(data = d6,x='x',y='y',color = colors[0])
plt.show()

# %%
#K_means
kmean = KMeans(n_clusters=k, random_state=0)
kmean.fit(d6[["x","y"]])
d6["km"] = kmean.labels_
print('KMeans', '\n', f'Silhouette Score: {silhouette_score(d6, d6["km"])}')
plt.scatter(data = d6,x='x',y='y',c= d6["km"])
plt.show()
# Out:
# KMeans
#  Silhouette Score: 0.675181685152293

# %%
#Hierarchical Agglomeretive
h = AgglomerativeClustering(k)
h.fit(d6[["x","y"]])
d6["h"] = h.labels_
print('Hierarchical Agglomeretive', '\n', f'Silhouette Score: {silhouette_score(d6, d6["h"])}')
plt.scatter(data = d6,x='x',y='y',c= d6["h"])
plt.show()
# Out:
# Hierarchical Agglomeretive
#  Silhouette Score: 0.6132628050809312

# %%
#DBSCAN Agglomeretive
db = DBSCAN(eps = 0.25, min_samples = 15)
db.fit(d6[["x","y"]])
d6["db"] = db.labels_
print('DBSCAN', '\n', f'Silhouette Score: {silhouette_score(d6, d6["db"])}')
plt.scatter(data = d6,x='x',y='y',c= d6["db"])
plt.show()
# Out:
# DBSCAN
#  Silhouette Score: 0.4419614908849949

# %%
#Gaussian Mixture
gm = GaussianMixture(9)
gm.fit(d6[["x","y"]])
d6["gm"] = gm.predict(d6[["x","y"]])
print('Gaussian Mixture', '\n', f'Silhouette Score: {silhouette_score(d6, d6["gm"])}')
plt.scatter(data = d6,x='x',y='y',c= d6["gm"])
plt.show()
# Out:
# Gaussian Mixture
#  Silhouette Score: 0.6960613144652325

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # try !!

# %% [markdown]
# # Elbow Method
#
# Read more [here](https://iopscience.iop.org/article/10.1088/1755-1315/31/1/012012/pdf) if math excites you.

# %%
d6 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM6.csv")
plt.scatter(data = d6,x='x',y='y',color = colors[1])
plt.show()

# %%
nn = NearestNeighbors()
nn.fit(d6[["x", "y"]])
distances, neighbors = nn.kneighbors(d6[["x", "y"]])
distances
# Out:
# array([[0.        , 0.03684825, 0.04030501, 0.04590079, 0.05392598],
#        [0.        , 0.05507723, 0.08873333, 0.08971409, 0.12342943],
#        [0.        , 0.01645639, 0.02192115, 0.02310727, 0.03911119],
#        ...,
#        [0.        , 0.06858274, 0.07297492, 0.07745852, 0.09775416],
#        [0.        , 0.45787187, 0.62298899, 0.69254845, 0.74727075],
#        [0.        , 0.33466104, 0.35798497, 0.40054126, 0.46562008]])

# %%
distances = np.sort(distances[:, k], axis = 0)

# %%
distances_df = pd.DataFrame({"distances": distances,
                             "index": list(range(0,len(distances)))})
print(distances_df)
# Out:
#      distances  index
# 0     0.021941      0
# 1     0.023107      1
# 2     0.023880      2
# 3     0.024644      3
# 4     0.025280      4
# ..         ...    ...
# 295   0.920569    295
# 296   0.933234    296
# 297   0.933944    297
# 298   0.995437    298
# 299   1.259398    299
#
# [300 rows x 2 columns]

# %%
plt.plot(distances_df['index'],distances_df['distances'])
